# %% [markdown]
# # Testing
#
# Just for example, let's see if we can do some basic operations on Finite-Rank Tensors with Sage Math according to [this doc page](https://doc.sagemath.org/html/en/reference/tensor_free_modules/sage/tensor/modules/tensor_with_indices.html)

# %%
# %display latex
import numpy as np
import scipy
from numpy import r_

from sage.tensor.modules.tensor_with_indices import TensorWithIndices

# %%
u, v = var('u,v')
fx = (3+sin(v)+cos(u))*cos(2*v)
fy = (3+sin(v)+cos(u))*sin(2*v)
fz = sin(u)+2*cos(v)

fx
# Out:
# (cos(u) + sin(v) + 3)*cos(2*v)

# %%
parametric_plot3d([fx, fy, fz], (u, 0, 2*pi), (v, 0, 2*pi), frame=False, color="red")
# Out:
# Graphics3d Object

# %%
x, y = var('x,y')
maxima("expr_1: 5*cos(x)*(cos(x/2)*cos(y) + sin(x/2)*sin(2*y)+ 3.0) - 10.0")
5*cos(x)*(sin(x/2)*sin(2*y)+cos(x/2)*cos(y)+3.0)-10.0
maxima("expr_2: -5*sin(x)*(cos(x/2)*cos(y) + sin(x/2)*sin(2*y)+ 3.0)").sage()
-5*(cos(1/2*x)*cos(y) + sin(1/2*x)*sin(2*y) + 3.0)*sin(x)
maxima("expr_3: 5*(-sin(x/2)*cos(y) + cos(x/2)*sin(2*y))")
#5*(cos(x/2)*sin(2*y)-sin(x/2)*cos(y))
# Out:
# 5*(cos(x/2)*sin(2*y)-sin(x/2)*cos(y))

# %%
d = { 0:[1,1,2], 1:[2,3], 2:[3], 3:[4,4] }
g = DiGraph(d)
g.plot()
# Out:
# Graphics object consisting of 18 graphics primitives
